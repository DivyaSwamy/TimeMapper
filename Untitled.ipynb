# %%
import pandas as pd
import pickle

# %%
dfg = pd.read_csv('distance_matrix.csv')

# %%
pickle_in = open('distance_matrix.pkl', 'wb')
pickle.dump(dfg,pickle_in)

# %%
pickle_in = open('distance_matrix.pkl', 'rb')

test = pickle.load(pickle_in)

# %%
zipcode = test ['origin_zipcode'] == 90012
tt = test['start_time']== '8:00 am'
#
record = test[zipcode & tt]
drop_column =  ['day', 'distance','id', 'origin_zipcode', 'start_time']
record = record.drop(drop_column, axis=1).reset_index(drop = True)
record.rename(columns = {'destination_zipcode':'zipcode'}, inplace = True)
#

# %%
record
# Out:
#     zipcode  transit_time_now  transit_time_traffic
# 0     90012                 1                     1
# 1     90005                16                    18
# 2     90027                22                    21
# 3     90017                 8                     9
# 4     90021                14                    12
# 5     90011                15                    17
# 6     90058                16                    18
# 7     90028                12                    17
# 8     90069                26                    37
# 9     90264                54                    75
# 10    90402                38                    57
# 11    90410                26                    56
# 12    91302                41                    69
# 13    91324                39                    44
# 14    91340                34                    33
# 15    91308                52                    58
# 16    91395                31                    32
# ...

# %%
column_names =  ['zipcode', 'transit_time_now', 'transit_time_traffic']

# %%
drop_column =  ['day', 'distance','id', 'origin_zipcode', 'start_time']

#record = record.drop(drop_column, axis=1).reset_index(drop = True)

# %%
# Out:
#     zipcode  transit_time_now  transit_time_traffic
# 0     90012                 1                     1
# 1     90005                16                    18
# 2     90027                22                    21
# 3     90017                 8                     9
# 4     90021                14                    12
# 5     90011                15                    17
# 6     90058                16                    18
# 7     90028                12                    17
# 8     90069                26                    37
# 9     90264                54                    75
# 10    90402                38                    57
# 11    90410                26                    56
# 12    91302                41                    69
# 13    91324                39                    44
# 14    91340                34                    33
# 15    91308                52                    58
# 16    91395                31                    32
# ...
